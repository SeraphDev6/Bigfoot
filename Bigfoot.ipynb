# %% [markdown]
# # Bigfoot Sighting Natural Language Processing
# ## Data courtesy of [Tim Renner and the Bigfoot Field Researchers Organization ](https://www.kaggle.com/datasets/thedevastator/unlocking-mysteries-of-bigfoot-through-sightings)

# %% [markdown]
# ## Import necessary modules

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Pull down our selected model for encoding the sighting reports as vectors
# ### In this case we are using [mpnet-base](https://huggingface.co/microsoft/mpnet-base), an all-round model trained to be used for a variety of use cases

# %%
model = SentenceTransformer("all-mpnet-base-v2")
model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %% [markdown]
# ## Load in the geocoded data that includes the reports

# %%
df = pd.read_csv("./data/bfro_reports_geocoded.csv")
df.head()
# Out:
#    index                                           observed  \
# 0      0  I was canoeing on the Sipsey river in Alabama....
# 1      1  Ed L. was salmon fishing with a companion in P...
# 2      2  While attending U.R.I in the Fall of 1974,I wo...
# 3      3  Hello, My name is Doug and though I am very re...
# 4      4  It was May 1984. Two friends and I were up in ...
#
#                                     location_details  \
# 0                                                NaN
# 1                  East side of Prince William Sound
# 2             Great swamp area, Narragansett Indians
# 3  I would rather not have exact location (listin...
# 4  Logging roads north west of Yamhill, OR, about...
#
#                            county         state  season  \
# 0                  Winston County       Alabama  Summer
# 1  Valdez-Chitina-Whittier County        Alaska    Fall
# 2               Washington County  Rhode Island    Fall
# 3                     York County  Pennsylvania  Summer
# 4                  Yamhill County        Oregon  Spring
#
#                                                title  latitude  longitude  \
# 0                                                NaN       NaN        NaN
# 1                                                NaN       NaN        NaN
# 2  Report 6496: Bicycling student has night encou...     41.45      -71.5
# 3                                                NaN       NaN        NaN
# 4                                                NaN       NaN        NaN
#
#          date  ...  moon_phase precip_intensity precip_probability  \
# 0         NaN  ...         NaN              NaN                NaN
# 1         NaN  ...         NaN              NaN                NaN
# 2  1974-09-20  ...        0.16              0.0                0.0
# 3         NaN  ...         NaN              NaN                NaN
# 4         NaN  ...         NaN              NaN                NaN
#
#    precip_type  pressure                 summary  uv_index  visibility  \
# 0          NaN       NaN                     NaN       NaN         NaN
# 1          NaN       NaN                     NaN       NaN         NaN
# 2          NaN   1020.61  Foggy until afternoon.       4.0        2.75
# 3          NaN       NaN                     NaN       NaN         NaN
# 4          NaN       NaN                     NaN       NaN         NaN
#
#    wind_bearing  wind_speed
# 0           NaN         NaN
# 1           NaN         NaN
# 2         198.0        6.92
# 3           NaN         NaN
# 4           NaN         NaN
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (5021, 29)

# %% [markdown]
# ## Check for null's in the column we plan to encode, and split the data based on nulls

# %%
df_with_observed = df[~df["observed"].isna()].copy()
df_without_observed = df[df["observed"].isna()].copy()
df_with_observed.shape
# Out:
# (4983, 29)

# %%
df_without_observed.sample(1)
# Out:
#       index observed                         location_details         county  \
# 1535   1535      NaN  It happened in Bancroft park in Lansing  Ingham County
#
#          state  season                                              title  \
# 1535  Michigan  Spring  Report 49621: Teen recounts possible encounter...
#
#       latitude  longitude        date  ...  moon_phase precip_intensity  \
# 1535  42.75195  -81.52805  2015-04-01  ...        0.41              0.0
#
#      precip_probability  precip_type  pressure                        summary  \
# 1535                0.0          NaN   1019.36  Mostly cloudy in the morning.
#
#       uv_index  visibility  wind_bearing  wind_speed
# 1535       5.0        10.0         137.0        3.21
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Perform the encoding, transforming paragraphs into 768 dimension vectors

# %%
embeddings = model.encode(list(df_with_observed["observed"]))
embeddings
# Out:
# array([[ 0.02051164,  0.02096521,  0.02246091, ...,  0.10477722,
#          0.00103394,  0.02230784],
#        [-0.04386169,  0.04560776, -0.03324964, ...,  0.08863181,
#          0.00317093,  0.01241465],
#        [ 0.03663173,  0.0735049 ,  0.00363371, ...,  0.04705494,
#          0.00171463, -0.00958929],
#        ...,
#        [ 0.03145492,  0.03121825, -0.00923622, ...,  0.06445298,
#          0.00094692,  0.0089708 ],
#        [ 0.02337824,  0.01296577,  0.00216981, ...,  0.07106277,
#          0.0101575 ,  0.00332086],
#        [ 0.02623024,  0.10074759,  0.00023831, ...,  0.03221185,
#         -0.02743666, -0.01710202]], dtype=float32)

# %% [markdown]
# ## Save the embeddings for later use, if desired

# %%
np.save("bigfoot_embeddings.npy",embeddings)

# %% [markdown]
# ## Get the mean of the vectors, for comparison

# %%
mean_embed = embeddings.mean(axis=0)
mean_embed.shape
# Out:
# (768,)

# %% [markdown]
# ## Calculate [cosign similarity](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.cosine_similarity.html) for each embedding, compared to the mean, and save the value to the dataframe

# %%
similarity_to_mean = [cosine_similarity(x.reshape(1,-1), mean_embed.reshape(1,-1))[0][0] for x in embeddings]
df_with_observed["similarity_to_mean"] = similarity_to_mean
df_with_observed.sample(10)
# Out:
#       index                                           observed  \
# 3836   3836  Near Cresent City: a television production cre...
# 1306   1306  I was hunting hogs and felt I was being watche...
# 510     510  10 of us rented a cabin in the woods Thursday ...
# 137     137  I have always wanted to tell this story to som...
# 3865   3865  I wanted to comment on your report case #8595....
# 2442   2442  Found a fresh footprint approximately 18" or s...
# 3048   3048  I was on the BFRO's West Virginia expedition t...
# 1029   1029  My name is Dustin Anderson and my friends name...
# 3340   3340  My name is  T.W. and I live in Arkansas. Befor...
# 4985   4985  In the fall of 1978 we were in the house eatin...
#
#                                        location_details             county  \
# 3836                                                NaN   Del Norte County
# 1306                             Near the Sabine River.        Wood County
# 510   It was in Hocking Hills area in Logan Ohio. We...       Perry County
# 137   From Hubert you can take Hwy. 172 to where it ...      Onslow County
# 3865                                                NaN   El Dorado County
# 2442                 North Fork of the Skokomish River.       Mason County
# 3048                         Along the Greenbrier River  Pocahontas County
# 1029  Toward the back of Mooormill,Out Lampa Valley ...        Coos County
# 3340  Right beside my house. I would say it had to h...      Conway County
# 4985  It's been a long time since we lived there. If...       Henry County
#
#                state  season  \
# 3836      California  Summer
# 1306           Texas  Winter
# 510             Ohio    Fall
# 137   North Carolina  Summer
# 3865      California  Summer
# 2442      Washington  Spring
# 3048   West Virginia  Spring
# 1029          Oregon  Summer
# 3340        Arkansas  Summer
# 4985        Kentucky    Fall
#
#                                                   title  latitude  longitude  \
# 3836                                                NaN       NaN        NaN
# 1306  Report 8376: Hog hunter encounters unknown ani...  32.69028  -95.61056
# 510   Report 67239: Cabin renters have sighting outs...  39.59607  -82.35291
# 137   Report 9750: Motorist observes bipedal animal ...  34.53784  -77.50434
# 3865  Report 8650: Brothers hear unusual, late-night...  38.71806 -120.56190
# 2442             Report 1567: Hikers find a large track  47.35420 -123.23340
# 3048  Report 13083: Participant observations during ...  38.10785  -80.19044
# 1029                                                NaN       NaN        NaN
# 3340                                                NaN       NaN        NaN
# 4985  Report 2383: Tall, hairy creature observed sta...  38.44148  -85.00160
#
#             date  ...  precip_intensity precip_probability precip_type  \
# 3836         NaN  ...               NaN                NaN         NaN
# 1306  2004-03-25  ...            0.0000               0.00         NaN
# 510   2020-10-31  ...            0.0007               0.11        rain
# 137   1999-07-16  ...            0.0006               0.73        rain
# 3865  2004-05-10  ...            0.0010               0.62        rain
# 2442  1996-04-14  ...            0.0000               0.00         NaN
# 3048  2005-04-09  ...            0.0000               0.00         NaN
# 1029         NaN  ...               NaN                NaN         NaN
# 3340         NaN  ...               NaN                NaN         NaN
# 4985  1978-09-30  ...               NaN                NaN         NaN
#
#       pressure                            summary  uv_index  visibility  \
# 3836       NaN                                NaN       NaN         NaN
# 1306   1021.64  Mostly cloudy throughout the day.       4.0        8.79
# 510    1027.70          Clear throughout the day.       4.0       10.00
# 137    1022.35       Partly cloudy until evening.      10.0        8.85
# 3865       NaN          Clear throughout the day.       0.0         NaN
# 2442   1016.13           Mostly cloudy overnight.       7.0        9.90
# 3048       NaN          Clear throughout the day.       9.0       10.00
# 1029       NaN                                NaN       NaN         NaN
# 3340       NaN                                NaN       NaN         NaN
# 4985       NaN                                NaN       NaN         NaN
#
#       wind_bearing  wind_speed  similarity_to_mean
# 3836           NaN         NaN            0.590819
# 1306         150.0       12.41            0.708542
# 510          134.0        3.94            0.804978
# 137          112.0        1.65            0.820102
# 3865         168.0        1.14            0.721236
# 2442         182.0        0.80            0.509357
# 3048          93.0        1.57            0.701987
# 1029           NaN         NaN            0.684169
# 3340           NaN         NaN            0.736541
# 4985           NaN         NaN            0.833205
#
# [10 rows x 30 columns]

# %% [markdown]
# ## Add `similarity_to_mean` column to null dataframe

# %%
df_without_observed["similarity_to_mean"] = np.nan

# %% [markdown]
# ## Union and sort the DataFrames

# %%
final_df = pd.concat([df_with_observed, df_without_observed]).sort_values("index")
final_df.shape
# Out:
# C:\Users\wgiles\AppData\Local\Temp\ipykernel_5348\3114886164.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_df = pd.concat([df_with_observed, df_without_observed]).sort_values("index")
# (5021, 30)

# %% [markdown]
# ## Save final df to csv

# %%
final_df.to_csv("bfro_reports_geocoded_with_similarity.csv", index=False)
